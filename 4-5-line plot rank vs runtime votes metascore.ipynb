# %% [markdown]
# ######
# #### We will see our own csvfile and will compare our own columns
# ######

# %%
import matplotlib.pyplot as plt
import pandas as pd

file = pd.read_csv('groupby(csvfile8).csv')
file
# Out:
#   College    Department  Student  Rank  Height(foot.inch)  Age
# 0     CAA       Pre-Eng   Rayyan     1                6.4   19
# 1     COD  Comp.Science    Ahmed     4                6.1   20
# 2     CAA       Pre-Eng    Qutub     2                5.8   20
# 3     FDC       Pre-Eng      Ali     8                5.9   21
# 4     COD  Comp.Science    Azhar    10                5.5   19
# 5     COD       Pre-Eng   Rizwan     3                6.0   23
# 6    PAF    Pre-Medical   Junaid     5                6.0   23
# 7     CAA   Pre-Medical  Shaheer     6                5.8   19
# 8     CAA  Comp.Science   Asshad     9                5.9   21
# 9     FDC       Pre-Eng    Abdul     7                5.7   20

# %%
import matplotlib.pyplot as plt
import pandas as pd

file = pd.read_csv('groupby(csvfile8).csv')

a = file['College']
b = file['Rank']
plt.figure(figsize = (10,3))
file, plt.plot(a,b)
# Out:
# (  College    Department  Student  Rank  Height(foot.inch)  Age
#  0     CAA       Pre-Eng   Rayyan     1                6.4   19
#  1     COD  Comp.Science    Ahmed     4                6.1   20
#  2     CAA       Pre-Eng    Qutub     2                5.8   20
#  3     FDC       Pre-Eng      Ali     8                5.9   21
#  4     COD  Comp.Science    Azhar    10                5.5   19
#  5     COD       Pre-Eng   Rizwan     3                6.0   23
#  6    PAF    Pre-Medical   Junaid     5                6.0   23
#  7     CAA   Pre-Medical  Shaheer     6                5.8   19
#  8     CAA  Comp.Science   Asshad     9                5.9   21
#  9     FDC       Pre-Eng    Abdul     7                5.7   20,
#  [<matplotlib.lines.Line2D at 0x1c698fee310>])

# %%
import matplotlib.pyplot as plt
import pandas as pd

file = pd.read_csv('groupby(csvfile8).csv')

plt.figure(figsize = (10,3))
a = file['Department']
b = file['College']
file, plt.plot(a,b)
# Out:
# (  College    Department  Student  Rank  Height(foot.inch)  Age
#  0     CAA       Pre-Eng   Rayyan     1                6.4   19
#  1     COD  Comp.Science    Ahmed     4                6.1   20
#  2     CAA       Pre-Eng    Qutub     2                5.8   20
#  3     FDC       Pre-Eng      Ali     8                5.9   21
#  4     COD  Comp.Science    Azhar    10                5.5   19
#  5     COD       Pre-Eng   Rizwan     3                6.0   23
#  6    PAF    Pre-Medical   Junaid     5                6.0   23
#  7     CAA   Pre-Medical  Shaheer     6                5.8   19
#  8     CAA  Comp.Science   Asshad     9                5.9   21
#  9     FDC       Pre-Eng    Abdul     7                5.7   20,
#  [<matplotlib.lines.Line2D at 0x1c699009990>])

# %%
import matplotlib.pyplot as plt
import pandas as pd

file = pd.read_csv('groupby(csvfile8).csv')

plt.figure(figsize = (10,3))
a = file['College']
b = file['Height(foot.inch)']
file, plt.plot(a,b)
# Out:
# (  College    Department  Student  Rank  Height(foot.inch)  Age
#  0     CAA       Pre-Eng   Rayyan     1                6.4   19
#  1     COD  Comp.Science    Ahmed     4                6.1   20
#  2     CAA       Pre-Eng    Qutub     2                5.8   20
#  3     FDC       Pre-Eng      Ali     8                5.9   21
#  4     COD  Comp.Science    Azhar    10                5.5   19
#  5     COD       Pre-Eng   Rizwan     3                6.0   23
#  6    PAF    Pre-Medical   Junaid     5                6.0   23
#  7     CAA   Pre-Medical  Shaheer     6                5.8   19
#  8     CAA  Comp.Science   Asshad     9                5.9   21
#  9     FDC       Pre-Eng    Abdul     7                5.7   20,
#  [<matplotlib.lines.Line2D at 0x1c698ec1390>])
