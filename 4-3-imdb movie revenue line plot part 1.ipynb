# %% [markdown]
# ###
# ## IMDB Movie Data Analysis:
# ###

# %% [markdown]
# #### We will use our own week1 and week2 csv files instead of imdb
# ######

# %%
import matplotlib.pyplot as plt
import pandas as pd

a = pd.read_csv('week01csvfile9.csv')
b = pd.read_csv('week2csvfile10.csv')
a
# Out:
#      Week  Sales  Profit (PKR)
# 0   week6    216         85000
# 1   week7    218         87000
# 2   week8    223         91000
# 3   week9    240        115000
# 4  week10    226         96000

# %%
b
# Out:
#     Week  Sales  Profit (PKR)
# 0  week1    219         98000
# 1  week2    235        110000
# 2  week3    230         95000
# 3  week4    228         92000
# 4  week5    215         87000

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy.random import randint

a = pd.read_csv('week01csvfile9.csv')
b = pd.read_csv('week2csvfile10.csv')
c = a['Sales']
d = a['Profit (PKR)']

c,plt.plot(c)
# Out:
# (0    216
#  1    218
#  2    223
#  3    240
#  4    226
#  Name: Sales, dtype: int64,
#  [<matplotlib.lines.Line2D at 0x1e0617d2790>])

# %%
c,d,plt.plot(c,d)
plt.xlabel('Sales')
plt.ylabel('Profit (in PKR)')
# Out:
# Text(0, 0.5, 'Profit (in PKR)')
